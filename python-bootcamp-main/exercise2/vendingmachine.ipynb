# %%
selections = {'Water': 75, 'Coke': 120, 'Diet Coke': 120, 'Iced tea': 100, 'Swiss Chocolate': 150, 'Candy': 95, 'Chips': 110, 'Bubble Gum': 50, 'Turkish Delight': 120}

# %%
num_items = [10, 10, 10, 10, 10, 10, 10, 10, 10]

# %%
ids = []
def show_menu():
        for a, b in selections.items():
            id = list(selections.keys()).index(a) + 1
            print(str(id), ":", a, " costs ", b, "cents")
            ids.append(id)

# %%
id = show_menu()
# Out:
# 1 : Water  costs  75 cents
# 2 : Coke  costs  120 cents
# 3 : Diet Coke  costs  120 cents
# 4 : Iced tea  costs  100 cents
# 5 : Swiss Chocolate  costs  150 cents
# 6 : Candy  costs  95 cents
# 7 : Chips  costs  110 cents
# 8 : Bubble Gum  costs  50 cents
# 9 : Turkish Delight  costs  120 cents

# %%
ids
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
purchase_ID = int(input('Put in purchase_ID:'))

# %%
secrete_PIN = 999

# %%
purchase_ID = 357
digits_purchase_ID = [int(d) for d in str(purchase_ID)]
items = []
for i in range(len(digits_purchase_ID)):
    digit = digits_purchase_ID[i]
    item_chosen = list(selections.values())[digit-1]
    items.append(item_chosen)
    total_amount_to_pay = 0
    for j in range(len(items)):
        total_amount_to_pay = total_amount_to_pay + items[j]
    num_items[digit-1] = num_items[digit-1] - 1
print("You gotta pay" + str(total_amount_to_pay))
    #total_amount_to_pay = total_amount_to_pay + item_chosen
    
num_items
# Out:
# You gotta pay380
# [70, 70, 69, 70, 69, 70, 69, 70, 70]

# %%
purchase_ID = 112
digits_purchase_ID = [int(d) for d in str(purchase_ID)]
len(digits_purchase_ID)
# Out:
# 3

# %%
def error_message():
    print("Error!")

# %%
items = []
item_names = []
transaction = []
def make_selection(purchase_ID):
    global ids
    secrete_PIN = 99
    if purchase_ID == secrete_PIN:
        #print_confidential_info()
        pass
    else:
        for i in range(len(digits_purchase_ID)):
            digit = digits_purchase_ID[i]
            if digit > len(ids) or purchase_ID <= 0:
                error_message()
            else:
                ids = set(ids)
                if digit in ids:
                    item_chosen = list(selections.values())[digit-1]
                    item_name = list(selections.keys())[digit-1]
                    items.append(item_chosen)
                    item_names.append(item_name)
                    total_amount_to_pay = 0
                    for j in range(len(items)):
                        total_amount_to_pay = total_amount_to_pay + items[j]
        transaction.append(total_amount_to_pay)
        print("You gotta pay: " + str(total_amount_to_pay))
        return total_amount_to_pay
make_selection(123)

item_names
# Out:
# You gotta pay: 380
# ['Diet Coke', 'Swiss Chocolate', 'Chips']

# %%
make_selection(123)
items
# Out:
# You gotta pay: 760
# [120, 150, 110, 120, 150, 110]

# %%
purchase_ID = 112
for i in range(len(digits_purchase_ID)):
            digit = digits_purchase_ID[i]
ids = set(ids)
if digit in ids:
                item_chosen = (list(selections.values()))[digit-1]
                
#total_amount_to_pay = 0
#total_amount_to_pay = total_amount_to_pay + item_chosen
print("You gotta pay:" + str(total_amount_to_pay) + "cents")
# Out:
# You gotta pay:120cents

# %%
total_price = []
digits= []

purchase_ID = 112
def make_selection():
    global purchase_ID
    digit = purchase_ID % 10
    global digit

    if purchase_ID == secret_PIN:
        print_confidential_info()
        else:
            error_message()
    elif purchase_ID < 0 or digit > len(selections.keys()):
        error_message()
    else:
        digits.append(digit)
        #item_price = list(selections.values())[digit-1]
        #total_price.append(item_price)
        purchase_ID //= 10
        print(digits)
        #print("The total amount to pay:" + total_amount)
        #return total_amount

# %%
transaction=[]
purchase_ID = 999
transaction.append(purchase_ID)
transaction
# Out:
# [999]

# %%
total_price
# Out:
# []

# %%
list(selections.values())[1]
# Out:
# 120

# %%
for i, a in zip(purchase_ID, selections.keys()):
            if i == list(selections.keys()).index(a) + 1:
                num_items[i-1] -= len(i)
        transaction.append(purchase_ID)

# %%
change_denom = [100, 50, 20, 10, 5]
num_coins = [5, 5, 5, 5, 5]
coins_4_change = [0, 0, 0, 0, 0]

# %%
coin_nb = []
def return_change():
    change_amount = 565
    print("Your change is: " + str(change_amount))
    if change_amount < 0:
        error_message()
    else:
        for i in range(len(change_denom)):
            coin_nb_for_denom = int(change_amount/change_denom[i])
            coin_nb.append(coin_nb_for_denom)
            if coin_nb[i] <= num_coins[i]:
                change_amount = change_amount - change_denom[i] * coin_nb[i]
                coins_4_change[i] = coins_4_change[i] + coin_nb[i]
                num_coins[i] = num_coins[i] - coin_nb[i]
                print("Please take " + str(coins_4_change[i]) + " of " + str(change_denom[i]))
            else:
                coin_nb[i] = 0 #if the coins needed for change > coins available, not use that denom at all
                print("We don't have enough " + str(change_denom[i]) + " cents for you!")
        print("End of transaction!")

# %%
return_change()
coins_4_change
coin_nb
# Out:
# Your change is: 565
# We don't have enough 100 cents for you!
# We don't have enough 50 cents for you!
# We don't have enough 20 cents for you!
# We don't have enough 10 cents for you!
# We don't have enough 5 cents for you!
# End of transaction!
# [0, 0, 0, 0, 0]

# %%
num_items_restocked = [10, 10, 10, 10, 10, 10, 10, 10, 10]
num_coins_restocked = [5, 5, 5, 5, 5]
def print_confidential_info():
    print("The number of items after restock: ") 
    for index, num_item in enumerate(num_items):
        num_items[index] = num_items[index] + num_items_restocked[index]
        print(list(selections.keys())[index] + " : " + str(num_items[index]))
    print("The number of coins after restock: ") 
    for indexx, num_coin in enumerate(num_coins):
        num_coins[indexx] = num_coins[indexx] + num_coins_restocked[indexx]
        print(str(change_denom[indexx]) + " : " + str(num_items[indexx]))

# %%
print_confidential_info()
# Out:
# The number of items after restock:
# Water : 70
# Coke : 70
# Diet Coke : 70
# Iced tea : 70
# Swiss Chocolate : 70
# Candy : 70
# Chips : 70
# Bubble Gum : 70
# Turkish Delight : 70
# The number of coins after restock:
# 100 : 70
# 50 : 70
# 20 : 70
# 10 : 70
# 5 : 70

# %%
num_items = [10, 10, 10, 10, 10, 10, 10, 10, 10]
num_items_restocked = [10, 10, 10, 10, 10, 10, 10, 10, 10]

num_items
# Out:
# [10, 10, 10, 10, 10, 10, 10, 10, 10]

# %%
transactions = [3, 4, 5, 6, 3]

for i in range(len(transactions)):

# %%
sales_per_item = {}

# iterating over the list
for item in item_names:
   # checking the element in dictionary
   if item in sales_per_item:
      # incrementing the count
      sales_per_item[item] += 3
   else:
      # initializing the count
      sales_per_item[item] = 1

# printing the frequency
print(sales_per_item)
# Out:
# {'Diet Coke': 1, 'Swiss Chocolate': 1, 'Chips': 1}

# %%
sales_per_item = {'Water': 3, 'Coke': 12, 'Diet Coke': 12}

# %%
def sales_each_item():
    #find frequency of items chosen
    sales_per_item = {}
    # iterating over the list
    for item in item_names:
    # checking the element in dictionary
        if item in sales_per_item:
            # incrementing the count
            sales_per_item[item] += 1
        else:
            # initializing the count
            sales_per_item[item] = 1
    #find individual sales for each item 
    common_set = set(sales_per_item.keys()).intersection(set(selections.keys()))
    common_set = list(common_set)
    sales_each_item = {}
    for selection in selections:
        if selection in common_set:
            sales_each_item[selection] = selections[selection]
    for key, value in sales_each_item.items():
        sales_each_item[key] = value * sales_per_item[key]

# %%
common_set = set(sales_per_item.keys()).intersection(set(selections.keys()))
common_set = list(common_set)
sales_each_item = {}
for selection in selections:
     if selection in common_set:
          sales_each_item[selection] = selections[selection]
for key, value in sales_each_item.items():
     sales_each_item[key] = value * sales_per_item[key]

# %%
sales_each_item
# Out:
# {'Water': 225, 'Coke': 1440, 'Diet Coke': 1440}
